# %%
import pandas as pd
import plotly.express as px

# %%
# Task 1

continent_df = df[df["continent"] == "Europe"]


plot_df = continent_df[continent_df["year"].isin([2002, 2007])]

fig = px.scatter(
    plot_df,
    x="gdpPercap",
    y="lifeExp",
    color="year",
    hover_name="country",
    title="Europe: GDP per Capita vs Life Expectancy (2002 vs 2007)",
    labels={
        "gdpPercap": "GDP per Capita",
        "lifeExp": "Life Expectancy"
    }
)

fig.update_layout(
    template="simple_white",
    height=600
)

fig.show()

# %%
# Task 2

plot_df = df[df["year"] == 2007].copy()

plot_df["highlight"] = plot_df["continent"].apply(
    lambda x: "Asia" if x == "Asia" else "Other Continents"
)

fig = px.scatter(
    plot_df,
    x="gdpPercap",
    y="lifeExp",
    size="pop",
    color="highlight",
    hover_name="country",
    size_max=50,
    log_x=True,
    color_discrete_map={
        "Asia": "#1f77b4",
        "Other Continents": "lightgrey"
    },
    title="Higher GDP Generally Corresponds to Longer Life Expectancy (2007)"
)

fig.add_annotation(
    x=40000,
    y=82,
    text="Wealthier countries tend to have higher life expectancy",
    showarrow=True,
    arrowhead=2
)

fig.update_layout(
    template="simple_white",
    height=700,
    legend_title=""
)

fig.show()
